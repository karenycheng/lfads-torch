# %% [markdown]
# plot pre vs z-scored data

# %% [markdown]
# 2. plot latents over entire experiment, then compute region contributions to each latent
# 3. trajectory through the latents
#
# - are there regions that encode only Odor (O)? only walk? the interaction of two stimuli?
# - trajectory differences across sensorimotor contexts?
#
# - how do we add external features (stimuli timings) "u" to lfads?

# %% [markdown]
# 2026.7.23
# finished items 2&3
#
# next: map latents to brain areas- loadings and visualize it overlaid on brain
#
# shyare with Atle the new training output on sciebo
# update fig 2 with region = 'name' not number
#
#
# on multisession vs single sessions
# try both and see which works better
# - add more data (KC)

# %% [markdown]
# correlate each factor for individual stimulus (0 and 1s )

# %% [markdown]
# #### 2026.83
# finished / setup code for correlating the factors with individual condition stimuli features
# to do: windowing the correlation for improved results // correlate only to onset frames
#
# next: map latent factors to brain regions
# gap: how to properly extract W between factors and firing rates (Claude uses lstsq from np.linalg)
# to do: reread papers and watch some tutorial videos from Chetan Pandarinath
# snel.ai

# %% [markdown]
# 2026.8.20
# - Atle finished the correlation plots
# - computed relative contributions of regions to factors, might have to think more about absolute values or not in normalization (non-abs seems more closely in line with lfads)
# - karen todo: plot a summary figure: overlay regions contributions per factor with brain template, plot the rates, and variance explained
#
# next: adapt approach to ICs, frame the correlations as decoding the sensorimotor contexts

# %% [markdown]
# 2026.8.25
# - logistic regression as decoder: try sparser time frames
# - alternative decoding approaches
# - karen to do from last time remains
# - ICs to do remains
