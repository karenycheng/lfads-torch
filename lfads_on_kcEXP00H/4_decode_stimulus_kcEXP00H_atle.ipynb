# %% [markdown]
# # Decoding odor, walk, and vision from LFADS factors — kcEXP00H
#
# This notebook is the kcEXP00H analogue of the velocity-decoding section in
# `tutorials/multisession/3_evaluation_KYC.ipynb`. Instead of decoding a *continuous*
# behavioral variable (hand velocity) with ridge regression, we decode three **binary,
# per-timepoint** stimulus channels — **odor**, **forward-walk (fw)**, and **vision** —
# with logistic regression.
#
# For each channel we ask two questions, exactly mirroring the Rouse tutorial:
#
# - **Within-fly**: is the stimulus readable from this fly's LFADS factors?
# - **Across-fly**: train on the other flies and test on a held-out fly. If this works, LFADS
#   found a **shared, fly-invariant latent code** for the stimulus across whole-brain region
#   sets that don't even have matching regions — the real multisession payoff.
#
# We also plot **time-resolved** decoding (one decoder per frame) to see *when* the latents
# start carrying each stimulus, and compare the predictive factor directions across the three
# channels.
#
# > **What goes into the decoder:** X = LFADS factors `(trials, time, n_factors)` flattened to
# > `(trials*time, n_factors)` — every timepoint is one sample. y = the binary stimulus state at
# > that timepoint. Model = `LogisticRegression` (classification), metric = **ROC-AUC** (odor and
# > vision are class-imbalanced, so raw accuracy is misleading).

# %% [markdown]
# ## Parameters

# %%
import re
import sys
from glob import glob
from pathlib import Path

import numpy as np
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 9

# --- Directory containing lfads_output_*.h5 (from run_posterior_sampling) ---
# Auto-pick the most recent run's best_model (same run the evaluation notebook used);
# or set H5_DIR explicitly to a best_model dir.
H5_DIR = None
if H5_DIR is None:
    cands = sorted(Path('../runs').glob(
        'kcEXP00H_multisession_202606291751/pbt/*/*/best_model'))
    cands = [c for c in cands if list(c.glob('lfads_output_*.h5'))]
    assert cands, 'No best_model with lfads_output_*.h5 found under ../runs'
    H5_DIR = cands[-1]
    print('Using LFADS outputs from:', H5_DIR)

# --- Directory with the source xarray (.nc) files holding the stimulus regressors ---
XARRAY_DIR = '../datasets/xarray_files/'
# Path so `utils.Xarray_UtilFns` is importable (provides load_group_xarrays). The utils package
# was copied into the lfads-torch repo root; this notebook runs from lfads_on_kcEXP00H/, so '..'.
sys.path.insert(0, '..')

# Onset marker only. NOTE: the model was trained on the WHOLE trial, so the decoder runs on
# the full source time axis (factors are (trials, ~1050, n_fac)). PRE/POST are no longer used
# to crop the primary targets — they only define the onset-windowed *control* cell at the end.
WIN_PRE = 25      # frames before odor onset (windowed-control cell only)
WIN_POST = 150    # frames after odor onset  (windowed-control cell only)

# Drop the experiment-start baseline trials (is_baseline==True; the user's trials 1 & 10).
# They are all-off AND confounded with experiment onset. The *randomized* xxx trials
# (condition=='xxx' & not baseline) are kept as legitimate all-off negatives.
EXCLUDE_BASELINE = True

H5_DIR = Path(H5_DIR)

# The three stimulus channels: name -> (per-timepoint state coord, per-trial presence coord)
MODALITIES = {
    'odor':   ('odor_state_frame', 'odor_trial_bool'),
    'walk':   ('fw_state_frame',   'fw_trial_bool'),
    'vision': ('vis_state_frame',  'vis_trial_bool'),
}
# Out:
# Using LFADS outputs from: ../runs/kcEXP00H_multisession_202606291751/pbt/kcEXP00H_multisession_zscored/260629/best_model

# %% [markdown]
# ## Load LFADS factors
#
# Same `merge_train_valid` helper as the evaluation notebook. Two gotchas carried over:
#
# - `train_inds` / `valid_inds` are stored as **float32** — cast to `int` before indexing.
# - Merging restores the **original trial order** (0..17), which is exactly the order the
#   stimulus regressors will be built in, so factors and targets line up trial-for-trial.

# %%
def merge_train_valid(train_data, valid_data, train_inds, valid_inds):
    n_samples = len(train_data) + len(valid_data)
    merged = np.full((n_samples, *train_data.shape[1:]), np.nan)
    merged[train_inds] = train_data
    merged[valid_inds] = valid_data
    return merged

h5_paths = sorted(glob(str(H5_DIR / 'lfads_output_*.h5')))
assert h5_paths, f"No lfads_output_*.h5 in {H5_DIR}"
print(f"Found {len(h5_paths)} HDF5 files")

factors = {}        # h5_stem -> (n_trials, n_time, n_fac)  in original trial order
h5_stems = []
for path in h5_paths:
    stem = Path(path).stem.replace('lfads_output_', '')
    h5_stems.append(stem)
    with h5py.File(path) as f:
        ti = f['train_inds'][()].astype(int)
        vi = f['valid_inds'][()].astype(int)
        factors[stem] = merge_train_valid(
            f['train_factors'][()], f['valid_factors'][()], ti, vi,
        )
    print(f"  {stem}: factors {factors[stem].shape}")
n_fac = next(iter(factors.values())).shape[-1]
print(f"n_factors = {n_fac}")
# Out:
# Found 5 HDF5 files
#   lfads_H30003-005_deltaF_Daqscans_BaseInterpPerRec_DVAP: factors (18, 1050, 50)
#   lfads_H34006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: factors (18, 1050, 50)
#   lfads_H35005-006_deltaF_Daqscans_BaseInterpPerRec_DVAP: factors (18, 1050, 50)
#   lfads_H36006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: factors (18, 1050, 50)
#   lfads_H37003-004_deltaF_Daqscans_BaseInterpPerRec_DVAP: factors (18, 1050, 50)
# n_factors = 50

# %% [markdown]
# ## Build the decoding targets from the xarray
#
# The stimulus regressors live in the source `.nc` files as coordinates:
#
# - `odor_state_frame`, `fw_state_frame`, `vis_state_frame` — the within-trial **on/off timing**
#   (0/1 along the shared full-trial `time` axis).
# - `odor_trial_bool`, `fw_trial_bool`, `vis_trial_bool` — whether each **trial** had that channel.
# - `condition` ∈ {`VOF,VOx,VxF,Vxx,xOF,xOx,xxF,xxx`} (V=vision, O=odor, F=fw; `x`=off).
#
# The full per-trial, per-timepoint binary regressor is
# `reg[trial, t] = trial_bool[trial] AND (state_frame[t] > 0)`.
#
# **Whole-trial (no crop):** the model was trained on the entire trial, so the factors span the full
# `time` axis (~1050 frames). We therefore build the targets over the **full axis** — *not* the old
# odor-onset window — so they line up frame-for-frame with the factors. We still record each fly's
# odor onset (`onset_frame`) for the onset marker and the windowed-control cell. We match each h5 file
# to its xarray by checking which `fly_id` appears in the h5 filename.
#
# > ⚠️ The old version cropped targets to a 175-frame window while the factors are ~1050 frames long;
# > that mismatch silently corrupts the flatten-and-decode alignment. Building full-length targets is
# > the fix.

# %%
from utils.Xarray_UtilFns import load_group_xarrays

ds_list = load_group_xarrays(XARRAY_DIR)
xa_by_flyid = {ds.attrs['fly_id']: ds for ds in ds_list}
print(f"Loaded {len(ds_list)} xarray datasets")

def find_xarray(h5_stem):
    # fly_id is the full filename stem and appears inside the h5 filename
    matches = [fid for fid in xa_by_flyid if fid in h5_stem]
    if len(matches) != 1:
        raise KeyError(f"{h5_stem}: matched {matches} (expected exactly 1)")
    return matches[0], xa_by_flyid[matches[0]]

# Whole-trial training: the factors span the FULL source time axis (~1050 frames), so build the
# targets over the full axis with NO odor-onset crop — that keeps them aligned frame-for-frame
# with the factors (the old PRE/POST crop made targets 175-long while factors are ~1050, which
# silently broke the flatten-and-decode alignment). We still record each fly's odor onset for the
# time-resolved plot's marker and for the onset-windowed control cell.
targets = {}      # h5_stem -> {modality -> (n_trials, n_time) binary}
baseline = {}     # h5_stem -> (n_trials,) bool
conditions = {}   # h5_stem -> (n_trials,) str
onset_frame = {}  # h5_stem -> int odor-onset frame on the full axis
for stem in h5_stems:
    fid, ds = find_xarray(stem)
    onset_frame[stem] = int(np.median(ds.attrs['odor_framestarts_within_trial']))
    targets[stem] = {}
    for mod, (state_var, bool_var) in MODALITIES.items():
        state = np.asarray(ds[state_var].values).reshape(-1)        # (n_time,)
        trial_b = np.asarray(ds[bool_var].values).reshape(-1)       # (n_trials,)
        full = (trial_b[:, None].astype(float) * (state[None, :] > 0)).astype(int)
        targets[stem][mod] = full                                   # (n_trials, n_time) WHOLE trial
    baseline[stem] = np.asarray(ds['is_baseline'].values).reshape(-1).astype(bool)
    conditions[stem] = np.asarray(ds['condition'].values).reshape(-1).astype(str)
    # Alignment sanity: targets must match factors in BOTH trials and time.
    nt, ntime = factors[stem].shape[:2]
    for mod in MODALITIES:
        assert targets[stem][mod].shape == (nt, ntime), \
            f"{stem}/{mod} shape {targets[stem][mod].shape} != {(nt, ntime)} (factors)"
    print(f"  {stem}: {nt} trials x {ntime} frames | onset~{onset_frame[stem]} | "
          + " ".join(f"{m}+={targets[stem][m].any(1).sum()}" for m in MODALITIES))
# Out:
#   H30003-005_deltaF_Daqscans_BaseInterpPerRec_DVAP  18 trials  conds: ['VOF', 'VOx', 'VxF', 'Vxx', 'xOF', 'xOx', 'xxF', 'xxx']
#   H34006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP  18 trials  conds: ['VOF', 'VOx', 'VxF', 'Vxx', 'xOF', 'xOx', 'xxF', 'xxx']
#   H35005-006_deltaF_Daqscans_BaseInterpPerRec_DVAP  18 trials  conds: ['VOF', 'VOx', 'VxF', 'Vxx', 'xOF', 'xOx', 'xxF', 'xxx']
#   H36006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP  18 trials  conds: ['VOF', 'VOx', 'VxF', 'Vxx', 'xOF', 'xOx', 'xxF', 'xxx']
#   H37003-004_deltaF_Daqscans_BaseInterpPerRec_DVAP  18 trials  conds: ['VOF', 'VOx', 'VxF', 'Vxx', 'xOF', 'xOx', 'xxF', 'xxx']
#
# Loaded 5 datasets from ../datasets/xarray_files/
# Loaded 5 xarray datasets
#   lfads_H30003-005_deltaF_Daqscans_BaseInterpPerRec_DVAP: 18 trials x 1050 frames | onset~451 | odor+=8 walk+=8 vision+=8
#   lfads_H34006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: 18 trials x 1050 frames | onset~451 | odor+=8 walk+=8 vision+=8
#   lfads_H35005-006_deltaF_Daqscans_BaseInterpPerRec_DVAP: 18 trials x 1050 frames | onset~451 | odor+=8 walk+=8 vision+=8
#   lfads_H36006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: 18 trials x 1050 frames | onset~451 | odor+=8 walk+=8 vision+=8
#   lfads_H37003-004_deltaF_Daqscans_BaseInterpPerRec_DVAP: 18 trials x 1050 frames | onset~451 | odor+=8 walk+=8 vision+=8

# %% [markdown]
# ### Handle the baseline / `xxx` trials
#
# `xxx` trials (all channels off) are valid **negatives** — you need stimulus-off trials to decode
# stimulus presence. But the **experiment-start baseline** trials (`is_baseline==True`) are all-off
# *and* confounded with experiment onset (different arousal/drift state), so by default we drop them
# from both factors and targets (applied identically, preserving alignment). The randomized `xxx`
# trials are kept.

# %%
factors_kept = {}
targets_kept = {}
for stem in h5_stems:
    keep = ~baseline[stem] if EXCLUDE_BASELINE else np.ones(len(baseline[stem]), bool)
    factors_kept[stem] = factors[stem][keep]
    targets_kept[stem] = {m: targets[stem][m][keep] for m in MODALITIES}
    n_xxx = (conditions[stem][keep] == 'xxx').sum()
    print(f"  {stem}: kept {keep.sum()}/{len(keep)} trials "
          f"(dropped {int((~keep).sum())} baseline) | randomized xxx negatives: {n_xxx}")
# Out:
#   lfads_H30003-005_deltaF_Daqscans_BaseInterpPerRec_DVAP: kept 16/18 trials (dropped 2 baseline) | randomized xxx negatives: 2
#   lfads_H34006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: kept 16/18 trials (dropped 2 baseline) | randomized xxx negatives: 2
#   lfads_H35005-006_deltaF_Daqscans_BaseInterpPerRec_DVAP: kept 16/18 trials (dropped 2 baseline) | randomized xxx negatives: 2
#   lfads_H36006-007_deltaF_Daqscans_BaseInterpPerRec_DVAP: kept 16/18 trials (dropped 2 baseline) | randomized xxx negatives: 2
#   lfads_H37003-004_deltaF_Daqscans_BaseInterpPerRec_DVAP: kept 16/18 trials (dropped 2 baseline) | randomized xxx negatives: 2

# %% [markdown]
# ## Decode: within-fly and across-fly
#
# For each fly and channel:
#
# - **within-fly** — split trials 70/30, train a logistic decoder on train-trial timepoints, score
#   ROC-AUC on test-trial timepoints.
# - **across-fly** — train on *all* timepoints from the other flies, test on the held-out fly.
#
# We use `class_weight="balanced"` (odor/vision are imbalanced) and return `NaN` when a split has
# only one class (so AUC is undefined).

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score


def _flat(X, y):
    return X.reshape(-1, X.shape[-1]), y.reshape(-1)


def fit_score(Xtr, ytr, Xte, yte):
    Xtr, ytr = _flat(Xtr, ytr)
    Xte, yte = _flat(Xte, yte)
    if len(np.unique(ytr)) < 2 or len(np.unique(yte)) < 2:
        return np.nan
    clf = LogisticRegression(class_weight='balanced', max_iter=1000)
    clf.fit(Xtr, ytr)
    p = clf.predict_proba(Xte)[:, 1]
    return roc_auc_score(yte, p)


def within_fly_split(n_trials, test_frac=0.3, seed=0):
    rng = np.random.RandomState(seed)
    perm = rng.permutation(n_trials)
    n_test = max(1, int(round(test_frac * n_trials)))
    return perm[n_test:], perm[:n_test]   # train_trials, test_trials


results = []
for mod in MODALITIES:
    for stem in h5_stems:
        Xf, yf = factors_kept[stem], targets_kept[stem][mod]
        # within-fly
        tr, te = within_fly_split(Xf.shape[0])
        auc_w = fit_score(Xf[tr], yf[tr], Xf[te], yf[te])
        results.append(dict(fly=stem, modality=mod,
                            holdout='within-fly', auc=auc_w))
        # across-fly
        Xtr = np.concatenate([factors_kept[s] for s in h5_stems if s != stem], 0)
        ytr = np.concatenate([targets_kept[s][mod] for s in h5_stems if s != stem], 0)
        auc_a = fit_score(Xtr, ytr, Xf, yf)
        results.append(dict(fly=stem, modality=mod,
                            holdout='across-fly', auc=auc_a))

results = pd.DataFrame(results)
results
# Out:
#                                                   fly modality     holdout  \
# 0   lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...     odor  within-fly
# 1   lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...     odor  across-fly
# 2   lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...     odor  within-fly
# 3   lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...     odor  across-fly
# 4   lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...     odor  within-fly
# 5   lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...     odor  across-fly
# 6   lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...     odor  within-fly
# 7   lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...     odor  across-fly
# 8   lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...     odor  within-fly
# 9   lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...     odor  across-fly
# 10  lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...     walk  within-fly
# 11  lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...     walk  across-fly
# 12  lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...     walk  within-fly
# 13  lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...     walk  across-fly
# 14  lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...     walk  within-fly
# 15  lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...     walk  across-fly
# 16  lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...     walk  within-fly
# 17  lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...     walk  across-fly
# 18  lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...     walk  within-fly
# 19  lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...     walk  across-fly
# 20  lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...   vision  within-fly
# 21  lfads_H30003-005_deltaF_Daqscans_BaseInterpPer...   vision  across-fly
# 22  lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...   vision  within-fly
# 23  lfads_H34006-007_deltaF_Daqscans_BaseInterpPer...   vision  across-fly
# 24  lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...   vision  within-fly
# 25  lfads_H35005-006_deltaF_Daqscans_BaseInterpPer...   vision  across-fly
# 26  lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...   vision  within-fly
# 27  lfads_H36006-007_deltaF_Daqscans_BaseInterpPer...   vision  across-fly
# 28  lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...   vision  within-fly
# 29  lfads_H37003-004_deltaF_Daqscans_BaseInterpPer...   vision  across-fly
#
#          auc
# 0   0.523712
# 1   0.536767
# 2   0.606849
# 3   0.647311
# 4   0.680964
# 5   0.699121
# 6   0.412677
# 7   0.594524
# 8   0.359858
# 9   0.654721
# 10  0.853316
# 11  0.747020
# 12  0.789333
# 13  0.720282
# 14  0.554015
# 15  0.673455
# 16  0.642883
# 17  0.753518
# 18  0.835009
# 19  0.746203
# 20  0.392712
# 21  0.586096
# 22  0.418699
# 23  0.641586
# 24  0.452197
# 25  0.685114
# 26  0.279774
# 27  0.567408
# 28  0.627024
# 29  0.642166

# %% [markdown]
# ### Plot decoding AUC by channel

# %%
import seaborn as sns

g_order = ['within-fly', 'across-fly']
fig, axes = plt.subplots(1, len(MODALITIES), figsize=(4 * len(MODALITIES), 4), sharey=True)
for ax, mod in zip(axes, MODALITIES):
    sub = results[results.modality == mod]
    sns.barplot(sub, x='holdout', y='auc', order=g_order, ax=ax,
                errorbar='se', capsize=0.15)
    sns.stripplot(sub, x='holdout', y='auc', order=g_order, ax=ax,
                  color='k', size=3, alpha=0.6)
    ax.axhline(0.5, color='grey', ls='--', lw=0.8)   # chance
    ax.set_ylim(0, 1)
    ax.set_title(mod)
    ax.set_xlabel('')
    ax.set_ylabel('Decoding ROC-AUC')
fig.suptitle('Stimulus decoding from LFADS factors (chance = 0.5)')
fig.tight_layout()

# %% [markdown]
# ## Time-resolved decoding
#
# Fit **one decoder per frame** (across-fly, leave-one-fly-out averaged) over the **whole trial** and
# plot AUC vs frame, with each fly's odor onset marked (red dotted line; we mark the mean onset). The
# curve shows the **onset latency** and **persistence** of each stimulus in the latent code. Frames
# are evaluated on a stride (`FRAME_STEP`) to keep ~1050 single-frame fits tractable.
#
# > **Lag note:** for *sensory* signals the neural response *follows* stimulus onset (the brain lags
# > the world) — the opposite of motor decoding, where neural activity leads behavior. We use lag 0
# > here; the rising edge of each curve already reveals the representational latency.
# >
# > **Read it against the onset line:** a curve that only rises **at/after** onset reflects genuine
# > stimulus encoding; one already elevated **before** onset is the trial-phase ramp confound that the
# > windowed-control cell below quantifies.

# %%
# Whole-trial time axis (no crop). One decoder per frame is expensive over ~1050 frames, so we
# evaluate on a strided subset of frames. Onset differs slightly per fly; we mark the mean onset.
n_time = factors_kept[h5_stems[0]].shape[1]
FRAME_STEP = 5
eval_frames = np.arange(0, n_time, FRAME_STEP)
mean_onset = int(np.mean([onset_frame[s] for s in h5_stems]))

fig, axes = plt.subplots(1, len(MODALITIES), figsize=(4 * len(MODALITIES), 3.5), sharey=True)
for ax, mod in zip(axes, MODALITIES):
    auc_t = np.full(len(eval_frames), np.nan)
    for i, t in enumerate(eval_frames):
        per_fly = []
        for stem in h5_stems:
            Xte = factors_kept[stem][:, t, :]
            yte = targets_kept[stem][mod][:, t]
            Xtr = np.concatenate(
                [factors_kept[s][:, t, :] for s in h5_stems if s != stem], 0)
            ytr = np.concatenate(
                [targets_kept[s][mod][:, t] for s in h5_stems if s != stem], 0)
            if len(np.unique(ytr)) < 2 or len(np.unique(yte)) < 2:
                continue
            clf = LogisticRegression(class_weight='balanced', max_iter=1000)
            clf.fit(Xtr, ytr)
            per_fly.append(roc_auc_score(yte, clf.predict_proba(Xte)[:, 1]))
        if per_fly:
            auc_t[i] = np.mean(per_fly)
    ax.plot(eval_frames, auc_t, lw=1.5)
    ax.axhline(0.5, color='grey', ls='--', lw=0.8)
    ax.axvline(mean_onset, color='r', ls=':', lw=1, label='odor onset')
    ax.set_ylim(0, 1)
    ax.set_title(mod)
    ax.set_xlabel('Frame (whole trial)')
    ax.set_ylabel('Across-fly ROC-AUC')
    ax.legend(loc='lower right', fontsize=7)
fig.suptitle('Time-resolved stimulus decoding (whole trial)')
fig.tight_layout()

# %% [markdown]
# ## Windowed control — guarding against the trial-phase confound
#
# Decoding on the **whole trial** means stimulus on/off is correlated with *time within the trial*,
# so a latent that merely tracks trial phase (the shared **PC1 ramp** from notebook 3) could inflate
# AUC without carrying any stimulus-*specific* signal. This cell re-runs the within/across decoders on
# a balanced window around each fly's odor onset (cropping **both** factors and targets), and compares:
#
# - **windowed AUC ≈ whole-trial AUC** → the latents carry genuine stimulus information.
# - **windowed collapses toward 0.5** while whole-trial stayed high → the whole-trial number was
#   mostly trial-phase, not stimulus identity.
#
# Also sanity-check the time-resolved curves above: a curve that only **rises at/after the red onset
# line** is real; one that's already high *before* onset is the ramp confound.

# %%
# --- Windowed control: decode only near odor onset (BOTH factors AND targets cropped) ---
# On the whole trial, stimulus on/off is correlated with time-in-trial, so a latent that merely
# tracks trial phase (e.g. the shared PC1 ramp seen in notebook 3) can inflate AUC without carrying
# stimulus-specific information. Cropping both factors and targets to a balanced window around each
# fly's onset breaks that correlation. If windowed AUC ~ whole-trial AUC, the latents carry real
# stimulus info; if windowed collapses toward 0.5, the whole-trial result was mostly trial-phase.

def crop_onset(stem):
    o = onset_frame[stem]
    sl = slice(o - WIN_PRE, o + WIN_POST)
    Xc = factors_kept[stem][:, sl, :]
    yc = {m: targets_kept[stem][m][:, sl] for m in MODALITIES}
    return Xc, yc

Xwin, ywin = {}, {}
for s in h5_stems:
    Xwin[s], ywin[s] = crop_onset(s)

ctrl_rows = []
for mod in MODALITIES:
    for stem in h5_stems:
        Xf, yf = Xwin[stem], ywin[stem][mod]
        tr, te = within_fly_split(Xf.shape[0])
        ctrl_rows.append(dict(fly=stem, modality=mod, holdout='within-fly',
                              auc=fit_score(Xf[tr], yf[tr], Xf[te], yf[te])))
        Xtr = np.concatenate([Xwin[s] for s in h5_stems if s != stem], 0)
        ytr = np.concatenate([ywin[s][mod] for s in h5_stems if s != stem], 0)
        ctrl_rows.append(dict(fly=stem, modality=mod, holdout='across-fly',
                              auc=fit_score(Xtr, ytr, Xf, yf)))
ctrl = pd.DataFrame(ctrl_rows)

# Compare whole-trial (results) vs onset-windowed (ctrl)
win_lab = f'onset[-{WIN_PRE},+{WIN_POST}]'
cmp = pd.concat([results.assign(window='whole-trial'),
                 ctrl.assign(window=win_lab)], ignore_index=True)
print(cmp.groupby(['modality', 'holdout', 'window']).auc.mean()
        .unstack('window').round(3))

fig, axes = plt.subplots(1, len(MODALITIES), figsize=(4 * len(MODALITIES), 4), sharey=True)
for ax, mod in zip(axes, MODALITIES):
    sub = cmp[cmp.modality == mod]
    sns.barplot(sub, x='holdout', y='auc', hue='window',
                order=['within-fly', 'across-fly'],
                hue_order=['whole-trial', win_lab], ax=ax, errorbar='se')
    ax.axhline(0.5, color='grey', ls='--', lw=0.8)
    ax.set_ylim(0, 1); ax.set_title(mod); ax.set_xlabel(''); ax.set_ylabel('ROC-AUC')
    ax.legend(fontsize=7)
fig.suptitle('Whole-trial vs onset-windowed decoding (trial-phase confound control)')
fig.tight_layout()
# Out:
# window               onset[-25,+150]  whole-trial
# modality holdout
# odor     across-fly            0.659        0.626
#          within-fly            0.628        0.517
# vision   across-fly            0.543        0.624
#          within-fly            0.619        0.434
# walk     across-fly            0.781        0.728
#          within-fly            0.831        0.735

# %% [markdown]
# ## Do the same factors carry odor, walk, and vision?
#
# Fit one logistic decoder per channel on all pooled timepoints (all flies) and compare the learned
# **factor-weight directions** via cosine similarity. High similarity between two channels means they
# ride on overlapping latent dimensions; low/negative means the model separates them into distinct
# factor subspaces. This connects to the readout-weight mapping in
# `5_region_contributions_kcEXP00H.ipynb` (which factors map onto which brain regions).

# %%
coefs = {}
for mod in MODALITIES:
    X = np.concatenate([factors_kept[s].reshape(-1, n_fac) for s in h5_stems], 0)
    y = np.concatenate([targets_kept[s][mod].reshape(-1) for s in h5_stems], 0)
    clf = LogisticRegression(class_weight='balanced', max_iter=1000)
    clf.fit(X, y)
    coefs[mod] = clf.coef_.reshape(-1)

mods = list(MODALITIES)
C = np.array([coefs[m] for m in mods])
C = C / (np.linalg.norm(C, axis=1, keepdims=True) + 1e-12)
cos = C @ C.T

fig, ax = plt.subplots(figsize=(4, 3.5))
im = ax.imshow(cos, vmin=-1, vmax=1, cmap='RdBu_r')
ax.set_xticks(range(len(mods))); ax.set_xticklabels(mods)
ax.set_yticks(range(len(mods))); ax.set_yticklabels(mods)
for i in range(len(mods)):
    for j in range(len(mods)):
        ax.text(j, i, f"{cos[i, j]:.2f}", ha='center', va='center', fontsize=8)
ax.set_title('Cosine similarity of\ndecoder factor-weight directions')
fig.colorbar(im, ax=ax, fraction=0.046)
fig.tight_layout()

# %% [markdown]
# ## Summary
#
# - **Within-fly AUC > 0.5** means a stimulus is readable from this fly's LFADS factors.
# - **Across-fly ≈ within-fly** means the latent code for that stimulus is **shared across flies** —
#   the multisession claim, despite each fly having different region sets.
# - The **time-resolved** curves show *when* each stimulus enters the latent code (onset latency)
#   and how long it persists.
# - The **cosine-similarity** matrix shows whether odor, walk, and vision share latent dimensions or
#   occupy distinct factor subspaces.
#
# To map the predictive factors back onto brain regions, continue in
# `5_region_contributions_kcEXP00H.ipynb`.
